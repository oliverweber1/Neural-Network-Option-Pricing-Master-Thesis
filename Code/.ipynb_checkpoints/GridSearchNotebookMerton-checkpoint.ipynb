# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from AnalyticFormulas import MertonJumpDiffusionPrice
from sklearn.model_selection import train_test_split, GridSearchCV #, RandomizedSearchCV
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from math import ceil

# %% [markdown]
# ## Option Prices

# %%
r = 0.07
sigma = 0.15
lam = 2
mu_j = 0.
sig_j = 0.1
s = 80
T = 1.
strikes = np.linspace(40, 300, 12500)
moneyness = s / strikes
prices = np.array([MertonJumpDiffusionPrice(s, r, sigma, T, k, mu_j, sig_j, lam) for k in strikes])
pricesNorm = prices / strikes

# %%
plt.figure(figsize=(8,4))
plt.plot(moneyness, pricesNorm)
plt.xlabel('$S/K')
plt.ylabel('$C(T,K)/K')
plt.title('Normalized Call Prices in Merton Jump Diffusion Model')
# Out:
# Text(0.5, 1.0, 'Normalized Call Prices in Merton Jump Diffusion Model')

# %% [markdown]
# ## Neural Net

# %%
X = np.reshape(moneyness, (len(moneyness), 1))
y = pricesNorm
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
def create_model(n_weights=1000, hidden_layers=1, learning_rate=0.001):
    # formulas derived from nWeights = sum (d(l-1)+1)*d(l) for all layers l with output dim d(l)
    if hidden_layers == 1: # 100% of neurons in first hidden layer
        neurons = [ceil((n_weights - 1) / 3)]
    elif hidden_layers == 2: # 70% / 30% split of neurons
        x = 1/7 * (np.sqrt(21 * n_weights + 79) - 10)
        neurons = list(map(ceil,[7/3 * x, x]))
    elif hidden_layers == 3: # 50% / 30% / 20% split
        x = 1/21 * (np.sqrt(84 * n_weights + 205) - 17)
        neurons = list(map(ceil, [5/2 * x, 3/2 * x, x]))
    else:
        raise Exception('Only 1, 2 or 3 layers allowed')
        
    model = Sequential([Dense(neurons[0], activation='relu', input_dim=1)])
    for n in neurons[1:]:
        model.add(Dense(n, activation='relu'))
    model.add(Dense(1))

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss='mse')

    return model

# %%
earlyStop = keras.callbacks.EarlyStopping(monitor='loss', patience=7, restore_best_weights=True)

batch_size = [16, 32, 64, 128, 256, 512, 1024, 2048]
learning_rate = [0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001]
hidden_layers = [1, 2, 3]
n_weights = [10, 30, 60, 100, 300, 600, 1000, 3000, 6000, 10000, 30000]

p_grid = dict(n_weights=n_weights, hidden_layers=hidden_layers, batch_size=batch_size, learning_rate=learning_rate)
#p_grid = dict(n_weights=n_weights, batch_size=batch_size, learning_rate=learning_rate)

results = {}

model = KerasRegressor(create_model, epochs=5000, verbose=0)
grid = GridSearchCV(estimator=model, param_grid=p_grid, n_jobs=-1, cv=5, verbose=1)
#grid_result = grid.fit(X_train, y_train, callbacks=[earlyStop])
grid_result = grid.fit(X_train, y_train, callbacks=[earlyStop])
print('Best: {} using {}'.format(grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 1848 candidates, totalling 9240 fits

# %%
print('Best: {} using {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -5.85104034667161e-11 using {'batch_size': 512, 'hidden_layers': 1, 'learning_rate': 0.005, 'n_weights': 10000}
# -0.000215 (0.000212) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 30}
# -0.000115 (0.000124) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 60}
# -0.000137 (0.000085) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 100}
# -0.000183 (0.000125) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 300}
# -0.038702 (0.002354) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 600}
# -0.037827 (0.002156) with: {'batch_size': 16, 'hidden_layers': 1, 'learning_rate': 0.1, 'n_weights': 1000}
# -0
with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 600}
# -0.014831 (0.018212) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 1000}
# -0.030349 (0.015337) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 3000}
# -0.039939 (0.005597) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 6000}
# -0.038592 (0.003289) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 10000}
# -0.037760 (0.002219) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.1, 'n_weights': 30000}
# -0.015102 (0.018540) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 30}
# -0.007391 (0.014657) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 60}
# -0.015365 (0.018741) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 100}
# -0.000030 (0.000048) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 300}
# -0.000003 (0.000002) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 600}
# -0.007410 (0.014817) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 1000}
# -0.000025 (0.000044) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 3000}
# -0.000001 (0.000001) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 6000}
# -0.000002 (0.000002) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 10000}
# -0.031851 (0.016460) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.05, 'n_weights': 30000}
# -0.022425 (0.018373) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 30}
# -0.007352 (0.014630) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 60}
# -0.007328 (0.014644) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 100}
# -0.000003 (0.000002) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 300}
# -0.000004 (0.000006) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 600}
# -0.000002 (0.000002) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 1000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 3000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 6000}
# -0.000001 (0.000001) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 10000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.01, 'n_weights': 30000}
# -0.030343 (0.015274) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 30}
# -0.015647 (0.019104) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 60}
# -0.023402 (0.019148) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 100}
# -0.007414 (0.014826) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 300}
# -0.000007 (0.000011) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 600}
# -0.000001 (0.000001) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 1000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 3000}
# -0.000002 (0.000003) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 6000}
# -0.000000 (0.000001) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 10000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.005, 'n_weights': 30000}
# -0.029826 (0.015007) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 30}
# -0.014786 (0.018007) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 60}
# -0.000029 (0.000043) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 100}
# -0.007417 (0.014823) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 300}
# -0.000001 (0.000001) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 600}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 1000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 3000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 6000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 10000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.001, 'n_weights': 30000}
# -0.029809 (0.015039) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 30}
# -0.030310 (0.015309) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 60}
# -0.000023 (0.000032) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 100}
# -0.000006 (0.000005) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 300}
# -0.000001 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 600}
# -0.000017 (0.000032) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 1000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 3000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 6000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 10000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0005, 'n_weights': 30000}
# -0.022399 (0.018393) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 30}
# -0.009596 (0.015323) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 60}
# -0.007441 (0.014811) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 100}
# -0.007413 (0.014825) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 300}
# -0.007914 (0.015826) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 600}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 1000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 3000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 6000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 10000}
# -0.000000 (0.000000) with: {'batch_size': 2048, 'hidden_layers': 3, 'learning_rate': 0.0001, 'n_weights': 30000}

# %%
columns = ['mean_fit_time', 'param_batch_size', 'param_hidden_layers', 'param_learning_rate', 'param_n_weights', 'mean_test_score', 'rank_test_score']
#columns = ['mean_fit_time', 'param_batch_size', 'param_learning_rate', 'param_n_weights', 'mean_test_score', 'rank_test_score']
result_df = pd.DataFrame(grid_result.cv_results_,)[columns]
result_df.columns = ['fit_time', 'batch_size', 'hidden_layers', 'learning_rate', 'n_weights', 'test_score', 'rank']
#result_df.columns = ['fit_time', 'batch_size', 'learning_rate', 'n_weights', 'test_score', 'rank']
result_df[['batch_size', 'hidden_layers', 'n_weights']] = result_df[['batch_size', 'hidden_layers', 'n_weights']].astype(int)
#result_df[['batch_size', 'n_weights']] = result_df[['batch_size', 'n_weights']].astype(int)
result_df['learning_rate'] = result_df['learning_rate'].astype('float')
result_df['test_score'] = -result_df['test_score']
result_df['actual_weights'] = result_df[['hidden_layers', 'n_weights']].apply(lambda x: create_model(x[1], x[0]).count_params(), axis=1)
#result_df['actual_weights'] = result_df['n_weights'].apply(lambda x: create_model(x).count_params())
result_df.head()
# Out:
#    fit_time  batch_size  hidden_layers  learning_rate  n_weights  test_score  \
# 0  8.287223          16              1            0.1         30    0.000215
# 1  8.077584          16              1            0.1         60    0.000115
# 2  7.629183          16              1            0.1        100    0.000137
# 3  8.702111          16              1            0.1        300    0.000183
# 4  8.609160          16              1            0.1        600    0.038702
#
#    rank  actual_weights
# 0  1096              31
# 1  1090              61
# 2  1092             100
# 3  1095             301
# 4  1663             601

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680 entries, 0 to 1679
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fit_time        1680 non-null   float64
#  1   batch_size      1680 non-null   int32
#  2   hidden_layers   1680 non-null   int32
#  3   learning_rate   1680 non-null   float64
#  4   n_weights       1680 non-null   int32
#  5   test_score      1680 non-null   float64
#  6   rank            1680 non-null   int32
#  7   actual_weights  1680 non-null   int64
# dtypes: float64(3), int32(4), int64(1)
# memory usage: 78.9 KB

# %%
result_df.describe()
# Out:
#           fit_time   batch_size  hidden_layers  learning_rate     n_weights  \
# count  1680.000000  1680.000000     1680.00000    1680.000000   1680.000000
# mean     28.710396   510.000000        2.00000       0.023800   5109.000000
# std      79.895094   662.722739        0.81674       0.035186   8865.176229
# min       2.101576    16.000000        1.00000       0.000100     30.000000
# 25%       6.428297    56.000000        1.00000       0.000500    100.000000
# 50%      13.004798   192.000000        2.00000       0.005000    800.000000
# 75%      23.857454   640.000000        3.00000       0.050000   6000.000000
# max    1745.517572  2048.000000        3.00000       0.100000  30000.000000
#
#          test_score         rank  actual_weights
# count  1.680000e+03  1680.000000     1680.000000
# mean   7.061769e-03   840.500000     5154.066667
# std    1.328902e-02   485.118542     8899.395032
# min    5.851040e-11     1.000000       31.000000
# 25%    8.827714e-08   420.750000      117.000000
# 50%    3.519514e-06   840.500000      813.000000
# 75%    7.941001e-03  1260.250000     6133.000000
# max    1.310895e-01  1680.000000    30244.000000

# %%
idx = result_df.groupby(['n_weights'])['test_score'].transform(min) == result_df['test_score']
best_results = result_df[idx].sort_values('n_weights')
best_results
# Out:
#         fit_time  batch_size  hidden_layers  learning_rate  n_weights  \
# 420     6.886172          64              1         0.1000         30
# 431     4.218112          64              1         0.0500         60
# 1272    3.885601        1024              1         0.0500        100
# 1493    4.629212        2048              1         0.0100        300
# 1494   10.192923        2048              1         0.0100        600
# 1075    6.858645         512              1         0.0100       1000
# 1286   63.624730        1024              1         0.0100       3000
# 1297   96.450484        1024              1         0.0050       6000
# 1088  106.750169         512              1         0.0050      10000
# 909   287.713742         256              1         0.0001      30000
#
#         test_score  rank  actual_weights
# 420   7.410991e-06   932              31
# 431   1.869915e-06   770              61
# 1272  6.240115e-07   646             100
# 1493  8.161471e-08   411             301
# 1494  8.120353e-09   162             601
# 1075  1.817123e-09    99            1000
# 1286  2.075852e-10    33            3001
# 1297  8.093550e-11     5            6001
# 1088  5.851040e-11     1           10000
# 909   6.709908e-11     4           30001

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots(figsize=(8.5,5.3))
ax.plot(best_results['actual_weights'], best_results['test_score'], '-o', c='gray', mfc='k', mec='k', markersize=8, label='Validation MSE')
ax.plot(best_results['actual_weights'], 1 / best_results['actual_weights'], c='navy', label='$M(\phi)^{-1}$')
ax.set_xlabel('Number of Weights')
ax.set_ylabel('Loss')
ax.set_title('Performance of Best Models', fontsize=11)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend()
plt.tight_layout()

# %%
result_df.to_csv('grid_search_Merton_20220113.csv')

# %%
overview = best_results.drop(['actual_weights', 'rank'], axis=1)
overview = overview[['n_weights', 'hidden_layers', 'test_score', 'learning_rate', 'batch_size', 'fit_time']]
#overview.set_index('n_weights', inplace=True)
overview.columns = ['Weights', 'Hidden Layers', 'Validation MSE', 'Learning Rate', 'Batch Size', 'Training Time (s)']
overview['Validation MSE'] = overview['Validation MSE'].apply(lambda x: '{:.2e}'.format(x))
overview['Learning Rate'] = overview['Learning Rate'].apply(lambda x: '{:g}'.format(x))
overview['Training Time (s)'] = overview['Training Time (s)'].apply(lambda x: '{:.2f}'.format(x))
overview
# Out:
#       Weights Validation MSE Learning Rate  Batch Size Training Time (s)
# 420        30       7.41e-06           0.1          64              6.89
# 431        60       1.87e-06          0.05          64              4.22
# 1272      100       6.24e-07          0.05        1024              3.89
# 1493      300       8.16e-08          0.01        2048              4.63
# 1494      600       8.12e-09          0.01        2048             10.19
# 1075     1000       1.82e-09          0.01         512              6.86
# 1286     3000       2.08e-10          0.01        1024             63.62
# 1297     6000       8.09e-11         0.005        1024             96.45
# 1088    10000       5.85e-11         0.005         512            106.75
# 909     30000       6.71e-11        0.0001         256            287.71

# %%
print(overview.to_latex(index=False))
# Out:
# \begin{tabular}{rllrl}
# \toprule
#  Weights & Validation MSE & Learning Rate &  Batch Size & Training Time (s) \\
# \midrule
#       30 &       7.41e-06 &           0.1 &          64 &              6.89 \\
#       60 &       1.87e-06 &          0.05 &          64 &              4.22 \\
#      100 &       6.24e-07 &          0.05 &        1024 &              3.89 \\
#      300 &       8.16e-08 &          0.01 &        2048 &              4.63 \\
#      600 &       8.12e-09 &          0.01 &        2048 &             10.19 \\
#     1000 &       1.82e-09 &          0.01 &         512 &              6.86 \\
#     3000 &       2.08e-10 &          0.01 &        1024 &             63.62 \\
#     6000 &       8.09e-11 &         0.005 &        1024 &             96.45 \\
#    10000 &       5.85e-11 &         0.005 &         512 &            106.75 \\
#    30000 &       6.71e-11 &        0.0001 &         256 &            287.71 \\
# \bottomrule
# \end{tabular}

# %%
X
# Out:
# array([[2.        ],
#        [1.99896046],
#        [1.99792199],
#        ...,
#        [0.26670365],
#        [0.26668516],
#        [0.26666667]])

# %%
X_train
# Out:
# array([[0.62831147],
#        [1.6627644 ],
#        [0.47579893],
#        ...,
#        [0.48614379],
#        [0.35154234],
#        [1.8697083 ]])
